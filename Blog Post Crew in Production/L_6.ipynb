# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 221 packages in 1.43s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# huggingface-hub ------------------------------     0 B/437.05 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# pydantic   ------------------------------     0 B/424.73 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# watchfiles ------------------------------     0 B/415.51 KiB
# pydantic   ------------------------------     0 B/424.73 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# openai     ------------------------------     0 B/380.49 KiB
# watchfiles ------------------------------     0 B/415.51 KiB
# pydantic   ------------------------------     0 B/424.73 KiB
# huggingface-hub ------------------------------     0 B/437.05 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/496.10 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# ipython    ------------------------------     0 B/800.69 KiB
# pygments   ------------------------------     0 B/1.15 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# kubernetes ------------------------------     0 B/1.77 MiB
# sqlalchemy ------------------------------     0 B/3.05 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# tzdata     ------------------------------ 14.88 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 8.34 KiB/351.46 KiB
# rpds-py    ------------------------------ 62.92 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/377.53 KiB
# openai     ------------------------------ 30.92 KiB/380.49 KiB
# langchain-core ------------------------------ 14.91 KiB/399.14 KiB
# watchfiles ------------------------------ 14.88 KiB/415.51 KiB
# pydantic   ------------------------------ 30.88 KiB/424.73 KiB
# huggingface-hub ------------------------------ 42.02 KiB/437.05 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 14.91 KiB/452.83 KiB
# cffi       ------------------------------ 62.88 KiB/456.29 KiB
# trio       ------------------------------ 46.92 KiB/470.44 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 48.69 KiB/523.63 KiB
# greenlet   ------------------------------ 16.00 KiB/588.29 KiB
# chromadb   ------------------------------ 14.92 KiB/601.07 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 46.92 KiB/774.15 KiB
# ipython    ------------------------------ 62.88 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# tzdata     ------------------------------ 14.88 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 33.25 KiB/351.46 KiB
# rpds-py    ------------------------------ 189.92 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/377.53 KiB
# openai     ------------------------------ 62.92 KiB/380.49 KiB
# langchain-core ------------------------------ 46.91 KiB/399.14 KiB
# watchfiles ------------------------------ 174.57 KiB/415.51 KiB
# pydantic   ------------------------------ 110.69 KiB/424.73 KiB
# huggingface-hub ------------------------------ 174.57 KiB/437.05 KiB
# httptools  ------------------------------ 158.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 14.91 KiB/452.83 KiB
# cffi       ------------------------------ 172.82 KiB/456.29 KiB
# trio       ------------------------------ 110.81 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 142.85 KiB/523.63 KiB
# greenlet   ------------------------------ 48.00 KiB/588.29 KiB
# chromadb   ------------------------------ 62.92 KiB/601.07 KiB
# pyvis      ------------------------------ 190.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 171.98 KiB/745.07 KiB
# regex      ------------------------------ 157.94 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# tzdata     ------------------------------ 30.88 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 49.25 KiB/351.46 KiB
# rpds-py    ------------------------------ 269.92 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 94.88 KiB/377.53 KiB
# openai     ------------------------------ 62.92 KiB/380.49 KiB
# langchain-core ------------------------------ 62.91 KiB/399.14 KiB
# watchfiles ------------------------------ 270.57 KiB/415.51 KiB
# pydantic   ------------------------------ 158.69 KiB/424.73 KiB
# huggingface-hub ------------------------------ 238.57 KiB/437.05 KiB
# httptools  ------------------------------ 246.13 KiB/449.01 KiB
# crewai-tools ------------------------------ 30.91 KiB/452.83 KiB
# cffi       ------------------------------ 254.76 KiB/456.29 KiB
# trio       ------------------------------ 142.81 KiB/470.44 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 238.85 KiB/523.63 KiB
# greenlet   ------------------------------ 287.51 KiB/588.29 KiB
# chromadb   ------------------------------ 71.97 KiB/601.07 KiB
# pyvis      ------------------------------ 286.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 267.98 KiB/745.07 KiB
# regex      ------------------------------ 253.83 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/216)
# tzdata     ------------------------------ 77.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 126.89 KiB/351.46 KiB
# rpds-py    ------------------------------ 333.92 KiB/351.99 KiB
# prompt-toolkit ------------------------------ 110.88 KiB/377.53 KiB
# openai     ------------------------------ 78.48 KiB/380.49 KiB
# langchain-core ------------------------------ 94.91 KiB/399.14 KiB
# watchfiles ------------------------------ 334.98 KiB/415.51 KiB
# pydantic   ------------------------------ 230.68 KiB/424.73 KiB
# huggingface-hub ------------------------------ 318.57 KiB/437.05 KiB
# httptools  ------------------------------ 318.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 46.91 KiB/452.83 KiB
# cffi       ------------------------------ 332.71 KiB/456.29 KiB
# trio       ------------------------------ 203.81 KiB/470.44 KiB
# pytz       ------------------------------ 105.74 KiB/496.10 KiB
# mpmath     ------------------------------ 323.59 KiB/523.63 KiB
# greenlet   ------------------------------ 367.51 KiB/588.29 KiB
# chromadb   ------------------------------ 110.92 KiB/601.07 KiB
# pyvis      ------------------------------ 366.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 335.98 KiB/745.07 KiB
# regex      ------------------------------ 317.84 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# tzdata     ------------------------------ 77.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 152.85 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 126.88 KiB/377.53 KiB
# openai     ------------------------------ 94.48 KiB/380.49 KiB
# langchain-core ------------------------------ 110.91 KiB/399.14 KiB
# watchfiles ------------------------------ 358.99 KiB/415.51 KiB
# pydantic   ------------------------------ 246.68 KiB/424.73 KiB
# huggingface-hub ------------------------------ 334.57 KiB/437.05 KiB
# httptools  ------------------------------ 334.91 KiB/449.01 KiB
# crewai-tools ------------------------------ 46.91 KiB/452.83 KiB
# cffi       ------------------------------ 332.82 KiB/456.29 KiB
# trio       ------------------------------ 251.81 KiB/470.44 KiB
# pytz       ------------------------------ 105.74 KiB/496.10 KiB
# mpmath     ------------------------------ 334.85 KiB/523.63 KiB
# greenlet   ------------------------------ 385.30 KiB/588.29 KiB
# chromadb   ------------------------------ 302.92 KiB/601.07 KiB
# pyvis      ------------------------------ 382.74 KiB/738.32 KiB
# pyyaml     ------------------------------ 361.96 KiB/745.07 KiB
# regex      ------------------------------ 333.94 KiB/774.15 KiB
# ipython    ------------------------------ 333.96 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# yarl       ------------------------------ 16.00 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 195.61 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 142.88 KiB/377.53 KiB
# openai     ------------------------------ 110.37 KiB/380.49 KiB
# langchain-core ------------------------------ 142.91 KiB/399.14 KiB
# watchfiles ------------------------------ 415.51 KiB/415.51 KiB
# pydantic   ------------------------------ 270.69 KiB/424.73 KiB
# huggingface-hub ------------------------------ 350.57 KiB/437.05 KiB
# httptools  ------------------------------ 392.56 KiB/449.01 KiB
# crewai-tools ------------------------------ 412.77 KiB/452.83 KiB
# cffi       ------------------------------ 380.82 KiB/456.29 KiB
# trio       ------------------------------ 299.81 KiB/470.44 KiB
# pytz       ------------------------------ 114.66 KiB/496.10 KiB
# mpmath     ------------------------------ 382.85 KiB/523.63 KiB
# greenlet   ------------------------------ 431.51 KiB/588.29 KiB
# chromadb   ------------------------------ 350.92 KiB/601.07 KiB
# pyvis      ------------------------------ 430.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 399.98 KiB/745.07 KiB
# regex      ------------------------------ 397.94 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# yarl       ------------------------------ 16.00 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 195.61 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 142.88 KiB/377.53 KiB
# openai     ------------------------------ 110.37 KiB/380.49 KiB
# langchain-core ------------------------------ 142.91 KiB/399.14 KiB
# pydantic   ------------------------------ 270.69 KiB/424.73 KiB
# huggingface-hub ------------------------------ 350.57 KiB/437.05 KiB
# httptools  ------------------------------ 408.56 KiB/449.01 KiB
# crewai-tools ------------------------------ 412.77 KiB/452.83 KiB
# cffi       ------------------------------ 396.82 KiB/456.29 KiB
# trio       ------------------------------ 299.81 KiB/470.44 KiB
# pytz       ------------------------------ 114.66 KiB/496.10 KiB
# mpmath     ------------------------------ 398.85 KiB/523.63 KiB
# greenlet   ------------------------------ 447.51 KiB/588.29 KiB
# chromadb   ------------------------------ 366.92 KiB/601.07 KiB
# pyvis      ------------------------------ 446.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 415.98 KiB/745.07 KiB
# regex      ------------------------------ 413.94 KiB/774.15 KiB
# ipython    ------------------------------ 349.96 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# pytest     ------------------------------ 16.00 KiB/334.32 KiB
# yarl       ------------------------------ 79.13 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 254.89 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 158.88 KiB/377.53 KiB
# openai     ------------------------------ 142.37 KiB/380.49 KiB
# langchain-core ------------------------------ 164.40 KiB/399.14 KiB
# pydantic   ------------------------------ 302.69 KiB/424.73 KiB
# huggingface-hub ------------------------------ 366.57 KiB/437.05 KiB
# crewai-tools ------------------------------ 412.77 KiB/452.83 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# trio       ------------------------------ 315.71 KiB/470.44 KiB
# pytz       ------------------------------ 114.66 KiB/496.10 KiB
# mpmath     ------------------------------ 414.85 KiB/523.63 KiB
# greenlet   ------------------------------ 495.51 KiB/588.29 KiB
# chromadb   ------------------------------ 366.92 KiB/601.07 KiB
# pyvis      ------------------------------ 510.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 462.26 KiB/745.07 KiB
# regex      ------------------------------ 461.94 KiB/774.15 KiB
# ipython    ------------------------------ 381.96 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# jiter      ------------------------------     0 B/311.67 KiB
# pytest     ------------------------------ 63.22 KiB/334.32 KiB
# yarl       ------------------------------ 111.03 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 270.89 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 190.67 KiB/377.53 KiB
# openai     ------------------------------ 158.48 KiB/380.49 KiB
# langchain-core ------------------------------ 180.40 KiB/399.14 KiB
# pydantic   ------------------------------ 350.69 KiB/424.73 KiB
# huggingface-hub ------------------------------ 382.57 KiB/437.05 KiB
# crewai-tools ------------------------------ 428.77 KiB/452.83 KiB
# trio       ------------------------------ 331.60 KiB/470.44 KiB
# pytz       ------------------------------ 114.66 KiB/496.10 KiB
# mpmath     ------------------------------ 478.85 KiB/523.63 KiB
# greenlet   ------------------------------ 526.92 KiB/588.29 KiB
# chromadb   ------------------------------ 366.92 KiB/601.07 KiB
# pyvis      ------------------------------ 533.20 KiB/738.32 KiB
# pyyaml     ------------------------------ 464.56 KiB/745.07 KiB
# regex      ------------------------------ 493.94 KiB/774.15 KiB
# ipython    ------------------------------ 397.96 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# jiter      ------------------------------     0 B/311.67 KiB
# pytest     ------------------------------ 63.22 KiB/334.32 KiB
# yarl       ------------------------------ 111.03 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 286.89 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 190.67 KiB/377.53 KiB
# openai     ------------------------------ 158.48 KiB/380.49 KiB
# langchain-core ------------------------------ 180.40 KiB/399.14 KiB
# pydantic   ------------------------------ 364.51 KiB/424.73 KiB
# huggingface-hub ------------------------------ 382.57 KiB/437.05 KiB
# crewai-tools ------------------------------ 428.77 KiB/452.83 KiB
# trio       ------------------------------ 331.60 KiB/470.44 KiB
# pytz       ------------------------------ 114.66 KiB/496.10 KiB
# mpmath     ------------------------------ 478.85 KiB/523.63 KiB
# greenlet   ------------------------------ 526.92 KiB/588.29 KiB
# chromadb   ------------------------------ 382.92 KiB/601.07 KiB
# pyvis      ------------------------------ 533.20 KiB/738.32 KiB
# pyyaml     ------------------------------ 464.56 KiB/745.07 KiB
# regex      ------------------------------ 493.94 KiB/774.15 KiB
# ipython    ------------------------------ 397.96 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# protobuf   ------------------------------ 14.88 KiB/309.20 KiB
# jiter      ------------------------------ 64.00 KiB/311.67 KiB
# pytest     ------------------------------ 111.22 KiB/334.32 KiB
# yarl       ------------------------------ 154.91 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 318.89 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 206.67 KiB/377.53 KiB
# openai     ------------------------------ 190.48 KiB/380.49 KiB
# langchain-core ------------------------------ 236.15 KiB/399.14 KiB
# huggingface-hub ------------------------------ 414.57 KiB/437.05 KiB
# crewai-tools ------------------------------ 444.77 KiB/452.83 KiB
# trio       ------------------------------ 363.81 KiB/470.44 KiB
# pytz       ------------------------------ 114.66 KiB/496.10 KiB
# mpmath     ------------------------------ 510.85 KiB/523.63 KiB
# greenlet   ------------------------------ 543.51 KiB/588.29 KiB
# chromadb   ------------------------------ 392.56 KiB/601.07 KiB
# pyvis      ------------------------------ 581.20 KiB/738.32 KiB
# pyyaml     ------------------------------ 512.56 KiB/745.07 KiB
# regex      ------------------------------ 541.94 KiB/774.15 KiB
# ipython    ------------------------------ 448.95 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# langsmith  ------------------------------ 9.10 KiB/299.43 KiB
# protobuf   ------------------------------ 77.54 KiB/309.20 KiB
# jiter      ------------------------------ 112.00 KiB/311.67 KiB
# pytest     ------------------------------ 175.22 KiB/334.32 KiB
# yarl       ------------------------------ 191.13 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# google-cloud-resource-manager ------------------------------ 351.46 KiB/351.46 KiB
# prompt-toolkit ------------------------------ 270.88 KiB/377.53 KiB
# openai     ------------------------------ 206.37 KiB/380.49 KiB
# langchain-core ------------------------------ 268.15 KiB/399.14 KiB
# huggingface-hub ------------------------------ 430.57 KiB/437.05 KiB
# crewai-tools ------------------------------ 444.77 KiB/452.83 KiB
# trio       ------------------------------ 411.81 KiB/470.44 KiB
# pytz       ------------------------------ 130.66 KiB/496.10 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# greenlet   ------------------------------ 559.51 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/601.07 KiB
# pyvis      ------------------------------ 638.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 575.98 KiB/745.07 KiB
# regex      ------------------------------ 605.94 KiB/774.15 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# langsmith  ------------------------------ 9.10 KiB/299.43 KiB
# protobuf   ------------------------------ 77.54 KiB/309.20 KiB
# jiter      ------------------------------ 112.00 KiB/311.67 KiB
# pytest     ------------------------------ 175.22 KiB/334.32 KiB
# yarl       ------------------------------ 191.13 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 270.88 KiB/377.53 KiB
# openai     ------------------------------ 206.37 KiB/380.49 KiB
# langchain-core ------------------------------ 268.15 KiB/399.14 KiB
# huggingface-hub ------------------------------ 430.57 KiB/437.05 KiB
# crewai-tools ------------------------------ 444.77 KiB/452.83 KiB
# trio       ------------------------------ 411.81 KiB/470.44 KiB
# pytz       ------------------------------ 130.66 KiB/496.10 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# greenlet   ------------------------------ 559.51 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/601.07 KiB
# pyvis      ------------------------------ 638.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 575.98 KiB/745.07 KiB
# regex      ------------------------------ 605.94 KiB/774.15 KiB
# ipython    ------------------------------ 461.96 KiB/800.69 KiB
# langchain  ------------------------------ 78.78 KiB/981.99 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# langsmith  ------------------------------ 9.10 KiB/299.43 KiB
# protobuf   ------------------------------ 93.54 KiB/309.20 KiB
# jiter      ------------------------------ 128.00 KiB/311.67 KiB
# pytest     ------------------------------ 191.22 KiB/334.32 KiB
# yarl       ------------------------------ 207.13 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 270.88 KiB/377.53 KiB
# openai     ------------------------------ 206.37 KiB/380.49 KiB
# langchain-core ------------------------------ 268.15 KiB/399.14 KiB
# huggingface-hub ------------------------------ 437.05 KiB/437.05 KiB
# crewai-tools ------------------------------ 444.77 KiB/452.83 KiB
# trio       ------------------------------ 411.81 KiB/470.44 KiB
# pytz       ------------------------------ 130.66 KiB/496.10 KiB
# greenlet   ------------------------------ 559.51 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/601.07 KiB
# pyvis      ------------------------------ 638.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 575.98 KiB/745.07 KiB
# regex      ------------------------------ 605.94 KiB/774.15 KiB
# ipython    ------------------------------ 461.96 KiB/800.69 KiB
# langchain  ------------------------------ 78.78 KiB/981.99 KiB
# tiktoken   ------------------------------ 638.69 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# langsmith  ------------------------------ 25.10 KiB/299.43 KiB
# protobuf   ------------------------------ 93.54 KiB/309.20 KiB
# jiter      ------------------------------ 128.00 KiB/311.67 KiB
# pytest     ------------------------------ 191.22 KiB/334.32 KiB
# yarl       ------------------------------ 207.13 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 286.88 KiB/377.53 KiB
# openai     ------------------------------ 206.37 KiB/380.49 KiB
# langchain-core ------------------------------ 268.15 KiB/399.14 KiB
# crewai-tools ------------------------------ 444.77 KiB/452.83 KiB
# trio       ------------------------------ 411.81 KiB/470.44 KiB
# pytz       ------------------------------ 130.66 KiB/496.10 KiB
# greenlet   ------------------------------ 559.51 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/601.07 KiB
# pyvis      ------------------------------ 638.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 575.98 KiB/745.07 KiB
# regex      ------------------------------ 605.94 KiB/774.15 KiB
# ipython    ------------------------------ 461.96 KiB/800.69 KiB
# langchain  ------------------------------ 78.78 KiB/981.99 KiB
# tiktoken   ------------------------------ 638.69 KiB/1.03 MiB
# pygments   ------------------------------ 524.35 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# langsmith  ------------------------------ 25.10 KiB/299.43 KiB
# protobuf   ------------------------------ 93.54 KiB/309.20 KiB
# jiter      ------------------------------ 128.00 KiB/311.67 KiB
# pytest     ------------------------------ 191.22 KiB/334.32 KiB
# yarl       ------------------------------ 207.13 KiB/335.33 KiB
# tzdata     ------------------------------ 93.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 286.88 KiB/377.53 KiB
# openai     ------------------------------ 206.37 KiB/380.49 KiB
# langchain-core ------------------------------ 286.91 KiB/399.14 KiB
# trio       ------------------------------ 411.81 KiB/470.44 KiB
# pytz       ------------------------------ 130.66 KiB/496.10 KiB
# greenlet   ------------------------------ 559.51 KiB/588.29 KiB
# chromadb   ------------------------------ 408.56 KiB/601.07 KiB
# pyvis      ------------------------------ 654.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 591.98 KiB/745.07 KiB
# regex      ------------------------------ 611.90 KiB/774.15 KiB
# ipython    ------------------------------ 461.96 KiB/800.69 KiB
# langchain  ------------------------------ 78.78 KiB/981.99 KiB
# tiktoken   ------------------------------ 654.69 KiB/1.03 MiB
# pygments   ------------------------------ 540.35 KiB/1.15 MiB
# aiohttp    ------------------------------ 637.35 KiB/1.23 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/216)
# qdrant-client ------------------------------ 46.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 61.43 KiB/267.39 KiB
# frozenlist ------------------------------ 46.91 KiB/268.43 KiB
# pypdf      ------------------------------ 41.32 KiB/290.99 KiB
# langsmith  ------------------------------ 85.85 KiB/299.43 KiB
# protobuf   ------------------------------ 157.54 KiB/309.20 KiB
# jiter      ------------------------------ 192.00 KiB/311.67 KiB
# pytest     ------------------------------ 255.22 KiB/334.32 KiB
# yarl       ------------------------------ 271.13 KiB/335.33 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 334.66 KiB/377.53 KiB
# openai     ------------------------------ 222.48 KiB/380.49 KiB
# langchain-core ------------------------------ 327.02 KiB/399.14 KiB
# trio       ------------------------------ 459.40 KiB/470.44 KiB
# pytz       ------------------------------ 142.16 KiB/496.10 KiB
# greenlet   ------------------------------ 575.51 KiB/588.29 KiB
# chromadb   ------------------------------ 440.56 KiB/601.07 KiB
# pyvis      ------------------------------ 718.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 652.86 KiB/745.07 KiB
# regex      ------------------------------ 685.94 KiB/774.15 KiB
# ipython    ------------------------------ 573.96 KiB/800.69 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# qdrant-client ------------------------------ 46.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 93.43 KiB/267.39 KiB
# frozenlist ------------------------------ 67.03 KiB/268.43 KiB
# pypdf      ------------------------------ 64.00 KiB/290.99 KiB
# langsmith  ------------------------------ 117.85 KiB/299.43 KiB
# protobuf   ------------------------------ 173.54 KiB/309.20 KiB
# jiter      ------------------------------ 224.00 KiB/311.67 KiB
# pytest     ------------------------------ 271.22 KiB/334.32 KiB
# yarl       ------------------------------ 303.13 KiB/335.33 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 340.23 KiB/377.53 KiB
# openai     ------------------------------ 222.48 KiB/380.49 KiB
# langchain-core ------------------------------ 334.91 KiB/399.14 KiB
# pytz       ------------------------------ 142.16 KiB/496.10 KiB
# greenlet   ------------------------------ 588.29 KiB/588.29 KiB
# chromadb   ------------------------------ 456.56 KiB/601.07 KiB
# pyvis      ------------------------------ 734.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 671.98 KiB/745.07 KiB
# regex      ------------------------------ 717.94 KiB/774.15 KiB
# ipython    ------------------------------ 573.96 KiB/800.69 KiB
# langchain  ------------------------------ 110.88 KiB/981.99 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# qdrant-client ------------------------------ 62.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 109.43 KiB/267.39 KiB
# frozenlist ------------------------------ 78.91 KiB/268.43 KiB
# pypdf      ------------------------------ 72.79 KiB/290.99 KiB
# langsmith  ------------------------------ 117.85 KiB/299.43 KiB
# protobuf   ------------------------------ 189.54 KiB/309.20 KiB
# jiter      ------------------------------ 240.00 KiB/311.67 KiB
# pytest     ------------------------------ 303.22 KiB/334.32 KiB
# yarl       ------------------------------ 319.13 KiB/335.33 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 356.23 KiB/377.53 KiB
# openai     ------------------------------ 222.48 KiB/380.49 KiB
# langchain-core ------------------------------ 350.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 456.56 KiB/601.07 KiB
# pyvis      ------------------------------ 734.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 687.98 KiB/745.07 KiB
# regex      ------------------------------ 733.94 KiB/774.15 KiB
# ipython    ------------------------------ 573.96 KiB/800.69 KiB
# langchain  ------------------------------ 110.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 734.91 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# cohere     ------------------------------     0 B/242.87 KiB
# qdrant-client ------------------------------ 62.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 125.32 KiB/267.39 KiB
# frozenlist ------------------------------ 78.91 KiB/268.43 KiB
# pypdf      ------------------------------ 88.79 KiB/290.99 KiB
# langsmith  ------------------------------ 144.00 KiB/299.43 KiB
# protobuf   ------------------------------ 203.64 KiB/309.20 KiB
# jiter      ------------------------------ 256.00 KiB/311.67 KiB
# pytest     ------------------------------ 303.22 KiB/334.32 KiB
# yarl       ------------------------------ 319.13 KiB/335.33 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# prompt-toolkit ------------------------------ 356.23 KiB/377.53 KiB
# openai     ------------------------------ 222.48 KiB/380.49 KiB
# langchain-core ------------------------------ 350.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# pyyaml     ------------------------------ 703.98 KiB/745.07 KiB
# regex      ------------------------------ 749.94 KiB/774.15 KiB
# ipython    ------------------------------ 573.96 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 750.91 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# google-cloud-bigquery ------------------------------     0 B/233.52 KiB
# rich       ------------------------------     0 B/236.74 KiB
# cohere     ------------------------------ 16.00 KiB/242.87 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 125.43 KiB/267.39 KiB
# frozenlist ------------------------------ 110.91 KiB/268.43 KiB
# pypdf      ------------------------------ 96.50 KiB/290.99 KiB
# langsmith  ------------------------------ 163.73 KiB/299.43 KiB
# protobuf   ------------------------------ 237.54 KiB/309.20 KiB
# jiter      ------------------------------ 288.00 KiB/311.67 KiB
# pytest     ------------------------------ 319.22 KiB/334.32 KiB
# yarl       ------------------------------ 335.13 KiB/335.33 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# openai     ------------------------------ 222.48 KiB/380.49 KiB
# langchain-core ------------------------------ 366.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# pyyaml     ------------------------------ 719.98 KiB/745.07 KiB
# regex      ------------------------------ 765.94 KiB/774.15 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# google-cloud-bigquery ------------------------------     0 B/233.52 KiB
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# cohere     ------------------------------ 16.00 KiB/242.87 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 135.61 KiB/267.39 KiB
# frozenlist ------------------------------ 110.91 KiB/268.43 KiB
# pypdf      ------------------------------ 112.50 KiB/290.99 KiB
# langsmith  ------------------------------ 163.73 KiB/299.43 KiB
# protobuf   ------------------------------ 237.54 KiB/309.20 KiB
# jiter      ------------------------------ 288.00 KiB/311.67 KiB
# pytest     ------------------------------ 334.32 KiB/334.32 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# langchain-core ------------------------------ 366.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# pyyaml     ------------------------------ 735.98 KiB/745.07 KiB
# regex      ------------------------------ 774.15 KiB/774.15 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 782.91 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# google-cloud-bigquery ------------------------------     0 B/233.52 KiB
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# cohere     ------------------------------ 32.00 KiB/242.87 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 135.61 KiB/267.39 KiB
# frozenlist ------------------------------ 126.91 KiB/268.43 KiB
# pypdf      ------------------------------ 112.50 KiB/290.99 KiB
# langsmith  ------------------------------ 163.73 KiB/299.43 KiB
# protobuf   ------------------------------ 248.52 KiB/309.20 KiB
# jiter      ------------------------------ 304.00 KiB/311.67 KiB
# pytest     ------------------------------ 334.32 KiB/334.32 KiB
# tzdata     ------------------------------ 109.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# langchain-core ------------------------------ 366.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# pyyaml     ------------------------------ 735.98 KiB/745.07 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 798.91 KiB/1.03 MiB
# pygments   ------------------------------ 780.35 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# google-cloud-bigquery ------------------------------     0 B/233.52 KiB
# rich       ------------------------------ 16.00 KiB/236.74 KiB
# cohere     ------------------------------ 32.00 KiB/242.87 KiB
# qdrant-client ------------------------------ 94.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 135.61 KiB/267.39 KiB
# frozenlist ------------------------------ 126.91 KiB/268.43 KiB
# pypdf      ------------------------------ 112.50 KiB/290.99 KiB
# langsmith  ------------------------------ 163.73 KiB/299.43 KiB
# protobuf   ------------------------------ 248.52 KiB/309.20 KiB
# jiter      ------------------------------ 304.00 KiB/311.67 KiB
# pytest     ------------------------------ 334.32 KiB/334.32 KiB
# tzdata     ------------------------------ 125.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# langchain-core ------------------------------ 366.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# pyyaml     ------------------------------ 735.98 KiB/745.07 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 798.91 KiB/1.03 MiB
# pygments   ------------------------------ 780.35 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# propcache  ------------------------------     0 B/230.48 KiB
# google-cloud-bigquery ------------------------------ 16.00 KiB/233.52 KiB
# rich       ------------------------------ 31.78 KiB/236.74 KiB
# cohere     ------------------------------ 32.00 KiB/242.87 KiB
# qdrant-client ------------------------------ 110.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 151.61 KiB/267.39 KiB
# frozenlist ------------------------------ 126.91 KiB/268.43 KiB
# pypdf      ------------------------------ 128.00 KiB/290.99 KiB
# langsmith  ------------------------------ 179.73 KiB/299.43 KiB
# protobuf   ------------------------------ 248.52 KiB/309.20 KiB
# jiter      ------------------------------ 304.00 KiB/311.67 KiB
# tzdata     ------------------------------ 125.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# langchain-core ------------------------------ 382.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# pyyaml     ------------------------------ 735.98 KiB/745.07 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 798.91 KiB/1.03 MiB
# pygments   ------------------------------ 796.35 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# python-dateutil ------------------------------     0 B/224.50 KiB
# alembic    ------------------------------     0 B/228.01 KiB
# propcache  ------------------------------ 14.91 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 32.00 KiB/233.52 KiB
# rich       ------------------------------ 47.78 KiB/236.74 KiB
# cohere     ------------------------------ 38.85 KiB/242.87 KiB
# qdrant-client ------------------------------ 110.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 167.61 KiB/267.39 KiB
# frozenlist ------------------------------ 142.91 KiB/268.43 KiB
# pypdf      ------------------------------ 128.00 KiB/290.99 KiB
# langsmith  ------------------------------ 192.00 KiB/299.43 KiB
# protobuf   ------------------------------ 262.21 KiB/309.20 KiB
# jiter      ------------------------------ 311.67 KiB/311.67 KiB
# tzdata     ------------------------------ 125.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# langchain-core ------------------------------ 382.91 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 814.91 KiB/1.03 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# python-dateutil ------------------------------     0 B/224.50 KiB
# alembic    ------------------------------     0 B/228.01 KiB
# propcache  ------------------------------ 14.91 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 32.00 KiB/233.52 KiB
# rich       ------------------------------ 47.78 KiB/236.74 KiB
# cohere     ------------------------------ 38.85 KiB/242.87 KiB
# qdrant-client ------------------------------ 110.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 167.61 KiB/267.39 KiB
# frozenlist ------------------------------ 142.91 KiB/268.43 KiB
# pypdf      ------------------------------ 128.00 KiB/290.99 KiB
# langsmith  ------------------------------ 192.00 KiB/299.43 KiB
# protobuf   ------------------------------ 262.21 KiB/309.20 KiB
# tzdata     ------------------------------ 125.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# langchain-core ------------------------------ 395.41 KiB/399.14 KiB
# pytz       ------------------------------ 158.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# ipython    ------------------------------ 623.66 KiB/800.69 KiB
# langchain  ------------------------------ 126.88 KiB/981.99 KiB
# tiktoken   ------------------------------ 814.91 KiB/1.03 MiB
# pygments   ------------------------------ 812.35 KiB/1.15 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (9/216)
# python-dateutil ------------------------------     0 B/224.50 KiB
# alembic    ------------------------------     0 B/228.01 KiB
# propcache  ------------------------------ 14.91 KiB/230.48 KiB
# google-cloud-bigquery ------------------------------ 32.00 KiB/233.52 KiB
# rich       ------------------------------ 47.78 KiB/236.74 KiB
# cohere     ------------------------------ 38.85 KiB/242.87 KiB
# qdrant-client ------------------------------ 110.91 KiB/260.91 KiB
# bcrypt     ------------------------------ 167.61 KiB/267.39 KiB
# frozenlist ------------------------------ 142.91 KiB/268.43 KiB
# pypdf      ------------------------------ 128.00 KiB/290.99 KiB
# langsmith  ------------------------------ 192.00 KiB/299.43 KiB
# protobuf   ------------------------------ 262.21 KiB/309.20 KiB
# tzdata     ------------------------------ 125.17 KiB/338.46 KiB
# openai     ------------------------------ 238.48 KiB/380.49 KiB
# pytz       ------------------------------ 174.16 KiB/496.10 KiB
# chromadb   ------------------------------ 472.34 KiB/601.07 KiB
# ...
# sympy      ------------------------------ 5.15 MiB/5.90 MiB
# pandas     ------------------------------ 10.39 MiB/12.45 MiB
# onnxruntime ------------------------------ 11.55 MiB/12.70 MiB
# uv         ------------------------------ 11.61 MiB/13.33 MiB
# numpy      ------------------------------ 11.38 MiB/17.41 MiB
# lancedb    ------------------------------ 11.82 MiB/25.87 MiB
# pylance    ------------------------------ 11.02 MiB/28.95 MiB
# ⠼ Preparing packages... (208/216) 9.83 MiB/38.19 MiB
# sympy      ------------------------------ 5.15 MiB/5.90 MiB
# pandas     ------------------------------ 10.92 MiB/12.45 MiB
# onnxruntime ------------------------------ 12.11 MiB/12.70 MiB
# uv         ------------------------------ 12.25 MiB/13.33 MiB
# numpy      ------------------------------ 12.19 MiB/17.41 MiB
# lancedb    ------------------------------ 12.47 MiB/25.87 MiB
# pylance    ------------------------------ 11.53 MiB/28.95 MiB
# ⠼ Preparing packages... (208/216) 11.24 MiB/38.19 MiB
# sympy      ------------------------------ 5.19 MiB/5.90 MiB
# pandas     ------------------------------ 11.39 MiB/12.45 MiB
# onnxruntime ------------------------------ 12.11 MiB/12.70 MiB
# numpy      ------------------------------ 13.30 MiB/17.41 MiB
# lancedb    ------------------------------ 12.47 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠼ Preparing packages... (208/216) 12.29 MiB/38.19 MiB
# sympy      ------------------------------ 5.20 MiB/5.90 MiB
# pandas     ------------------------------ 11.93 MiB/12.45 MiB
# onnxruntime ------------------------------ 12.11 MiB/12.70 MiB
# numpy      ------------------------------ 13.62 MiB/17.41 MiB
# lancedb    ------------------------------ 12.47 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠴ Preparing packages... (209/216) 12.60 MiB/38.19 MiB
# sympy      ------------------------------ 5.31 MiB/5.90 MiB
# onnxruntime ------------------------------ 12.11 MiB/12.70 MiB
# numpy      ------------------------------ 14.11 MiB/17.41 MiB
# lancedb    ------------------------------ 12.47 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠴ Preparing packages... (209/216) 13.09 MiB/38.19 MiB
# sympy      ------------------------------ 5.56 MiB/5.90 MiB
# onnxruntime ------------------------------ 12.11 MiB/12.70 MiB
# numpy      ------------------------------ 15.28 MiB/17.41 MiB
# lancedb    ------------------------------ 12.47 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠴ Preparing packages... (209/216) 14.29 MiB/38.19 MiB
# sympy      ------------------------------ 5.64 MiB/5.90 MiB
# onnxruntime ------------------------------ 12.11 MiB/12.70 MiB
# numpy      ------------------------------ 15.78 MiB/17.41 MiB
# lancedb    ------------------------------ 12.49 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠴ Preparing packages... (209/216) 14.87 MiB/38.19 MiB
# sympy      ------------------------------ 5.64 MiB/5.90 MiB
# onnxruntime ------------------------------ 12.21 MiB/12.70 MiB
# numpy      ------------------------------ 15.78 MiB/17.41 MiB
# lancedb    ------------------------------ 14.73 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠴ Preparing packages... (209/216) 14.87 MiB/38.19 MiB
# sympy      ------------------------------ 5.64 MiB/5.90 MiB
# numpy      ------------------------------ 15.78 MiB/17.41 MiB
# lancedb    ------------------------------ 15.38 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠦ Preparing packages... (211/216) 14.87 MiB/38.19 MiB
# sympy      ------------------------------ 5.64 MiB/5.90 MiB
# numpy      ------------------------------ 15.78 MiB/17.41 MiB
# lancedb    ------------------------------ 15.52 MiB/25.87 MiB
# pylance    ------------------------------ 11.64 MiB/28.95 MiB
# ⠦ Preparing packages... (211/216) 14.87 MiB/38.19 MiB
# sympy      ------------------------------ 5.64 MiB/5.90 MiB
# numpy      ------------------------------ 15.78 MiB/17.41 MiB
# lancedb    ------------------------------ 16.52 MiB/25.87 MiB
# pylance    ------------------------------ 14.08 MiB/28.95 MiB
# ⠦ Preparing packages... (211/216) 14.87 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.78 MiB/17.41 MiB
# lancedb    ------------------------------ 18.68 MiB/25.87 MiB
# pylance    ------------------------------ 17.16 MiB/28.95 MiB
# ⠦ Preparing packages... (211/216) 14.87 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 19.54 MiB/25.87 MiB
# pylance    ------------------------------ 17.58 MiB/28.95 MiB
# ⠧ Preparing packages... (211/216) 14.92 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 19.54 MiB/25.87 MiB
# pylance    ------------------------------ 17.58 MiB/28.95 MiB
# ⠧ Preparing packages... (211/216) 16.12 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 19.59 MiB/25.87 MiB
# pylance    ------------------------------ 17.58 MiB/28.95 MiB
# ⠧ Preparing packages... (211/216) 16.12 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 19.60 MiB/25.87 MiB
# pylance    ------------------------------ 17.58 MiB/28.95 MiB
# ⠧ Preparing packages... (211/216) 16.12 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 22.34 MiB/25.87 MiB
# pylance    ------------------------------ 19.33 MiB/28.95 MiB
# ⠇ Preparing packages... (211/216) 16.12 MiB/38.19 MiB
# sympy      ------------------------------ 5.66 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 23.85 MiB/25.87 MiB
# pylance    ------------------------------ 21.38 MiB/28.95 MiB
# ⠇ Preparing packages... (211/216) 18.02 MiB/38.19 MiB
# sympy      ------------------------------ 5.67 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 23.85 MiB/25.87 MiB
# pylance    ------------------------------ 21.38 MiB/28.95 MiB
# ⠇ Preparing packages... (211/216) 18.02 MiB/38.19 MiB
# sympy      ------------------------------ 5.69 MiB/5.90 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 23.85 MiB/25.87 MiB
# pylance    ------------------------------ 21.38 MiB/28.95 MiB
# ⠇ Preparing packages... (211/216) 18.02 MiB/38.19 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 23.85 MiB/25.87 MiB
# pylance    ------------------------------ 21.38 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 18.02 MiB/38.19 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 23.85 MiB/25.87 MiB
# pylance    ------------------------------ 21.38 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 18.02 MiB/38.19 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 23.93 MiB/25.87 MiB
# pylance    ------------------------------ 21.38 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 18.02 MiB/38.19 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# lancedb    ------------------------------ 25.87 MiB/25.87 MiB
# pylance    ------------------------------ 23.11 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 18.87 MiB/38.19 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# pylance    ------------------------------ 23.47 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 18.87 MiB/38.19 MiB
# numpy      ------------------------------ 15.97 MiB/17.41 MiB
# pylance    ------------------------------ 24.92 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 19.26 MiB/38.19 MiB
# numpy      ------------------------------ 16.04 MiB/17.41 MiB
# pylance    ------------------------------ 24.92 MiB/28.95 MiB
# ⠋ Preparing packages... (212/216) 19.26 MiB/38.19 MiB
# pylance    ------------------------------ 24.92 MiB/28.95 MiB
# ⠙ Preparing packages... (214/216) 19.26 MiB/38.19 MiB
# pylance    ------------------------------ 24.92 MiB/28.95 MiB
# ⠙ Preparing packages... (214/216) 19.26 MiB/38.19 MiB
# pylance    ------------------------------ 26.72 MiB/28.95 MiB
# ⠙ Preparing packages... (214/216) 19.26 MiB/38.19 MiB
# pylance    ------------------------------ 26.94 MiB/28.95 MiB
# ⠙ Preparing packages... (214/216) 19.35 MiB/38.19 MiB
# pylance    ------------------------------ 27.68 MiB/28.95 MiB
# ⠹ Preparing packages... (214/216) 20.53 MiB/38.19 MiB
# pylance    ------------------------------ 27.68 MiB/28.95 MiB
# ⠹ Preparing packages... (214/216) 20.65 MiB/38.19 MiB
# pylance    ------------------------------ 27.77 MiB/28.95 MiB
# ⠹ Preparing packages... (214/216) 20.65 MiB/38.19 MiB
# pylance    ------------------------------ 28.73 MiB/28.95 MiB
# ⠹ Preparing packages... (214/216) 20.65 MiB/38.19 MiB
# ⠹ Preparing packages... (214/216) 20.65 MiB/38.19 MiB
# ⠸ Preparing packages... (215/216) 20.70 MiB/38.19 MiB
# ⠸ Preparing packages... (215/216) 21.01 MiB/38.19 MiB
# ⠸ Preparing packages... (215/216) 22.61 MiB/38.19 MiB
# ⠼ Preparing packages... (215/216) 26.37 MiB/38.19 MiB
# ⠼ Preparing packages... (215/216) 26.64 MiB/38.19 MiB
# ⠼ Preparing packages... (215/216) 26.69 MiB/38.19 MiB
# ⠼ Preparing packages... (215/216) 26.71 MiB/38.19 MiB
# ⠼ Preparing packages... (215/216) 26.73 MiB/38.19 MiB
# ⠴ Preparing packages... (215/216) 30.09 MiB/38.19 MiB
# ⠴ Preparing packages... (215/216) 31.28 MiB/38.19 MiB
# ⠴ Preparing packages... (215/216) 31.52 MiB/38.19 MiB
# ⠴ Preparing packages... (215/216) 31.57 MiB/38.19 MiB
# ⠴ Preparing packages... (215/216) 35.43 MiB/38.19 MiB
# Prepared 216 packages in 6.43s
# Installed 216 packages in 244ms
#  + aiohappyeyeballs==2.4.3
#  + aiohttp==3.10.10
#  + aiosignal==1.3.1
#  + alembic==1.14.0
#  + annotated-types==0.7.0
#  + anyio==4.6.2.post1
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==2.4.1
#  + attrs==24.2.0
#  + auth0-python==4.7.2
#  + backoff==2.2.1
#  + bcrypt==4.2.0
#  + beautifulsoup4==4.12.3
#  + build==1.2.2.post1
#  + cachetools==5.5.0
#  + certifi==2024.8.30
#  + cffi==1.17.1
#  + charset-normalizer==3.4.0
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.18
#  + click==8.1.7
#  + cohere==5.11.3
#  + coloredlogs==15.0.1
#  + crewai==0.76.9
#  + crewai-tools==0.13.4
#  + cryptography==43.0.3
#  + dataclasses-json==0.6.7
#  + decorator==5.1.1
#  + deprecated==1.2.14
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + docx2txt==0.8
#  + durationpy==0.9
#  + embedchain==0.1.125
#  + executing==2.1.0
#  + fastapi==0.115.4
#  + fastavro==1.9.7
#  + filelock==3.16.1
#  + flatbuffers==24.3.25
#  + frozenlist==1.5.0
#  + fsspec==2024.10.0
#  + google-api-core==2.22.0
#  + google-auth==2.36.0
#  + google-cloud-aiplatform==1.71.1
#  + google-cloud-bigquery==3.26.0
#  + google-cloud-core==2.4.1
#  + google-cloud-resource-manager==1.13.0
#  + google-cloud-storage==2.18.2
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.65.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.13.1
#  + grpcio==1.67.1
#  + grpcio-status==1.67.1
#  + grpcio-tools==1.67.1
#  + h11==0.14.0
#  + h2==4.1.0
#  + hpack==4.0.0
#  + httpcore==1.0.6
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.26.2
#  + humanfriendly==10.0
#  + hyperframe==6.0.1
#  + idna==3.10
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.4.5
#  + iniconfig==2.0.0
#  + instructor==1.6.3
#  + ipython==8.29.0
#  + jedi==0.19.1
#  + jinja2==3.1.4
#  + jiter==0.5.0
#  + json-repair==0.30.1
#  + jsonpatch==1.33
#  + jsonpickle==3.4.2
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==31.0.0
#  + lancedb==0.15.0
#  + langchain==0.3.7
#  + langchain-cohere==0.3.1
#  + langchain-community==0.3.4
#  + langchain-core==0.3.15
#  + langchain-experimental==0.3.3
#  + langchain-openai==0.2.6
#  + langchain-text-splitters==0.3.2
#  + langsmith==0.1.141
#  + litellm==1.52.1
#  + mako==1.3.6
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.23.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.29
#  + mmh3==5.0.1
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==1.26.4
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.0
#  + openai==1.54.3
#  + opentelemetry-api==1.28.0
#  + opentelemetry-exporter-otlp-proto-common==1.28.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.28.0
#  + opentelemetry-exporter-otlp-proto-http==1.28.0
#  + opentelemetry-instrumentation==0.49b0
#  + opentelemetry-instrumentation-asgi==0.49b0
#  + opentelemetry-instrumentation-fastapi==0.49b0
#  + opentelemetry-proto==1.28.0
#  + opentelemetry-sdk==1.28.0
#  + opentelemetry-semantic-conventions==0.49b0
#  + opentelemetry-util-http==0.49b0
#  + orjson==3.10.11
#  + outcome==1.3.0.post0
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parameterized==0.9.0
#  + parso==0.8.4
#  + pexpect==4.9.0
#  + pluggy==1.5.0
#  + portalocker==2.10.1
#  + posthog==3.7.0
#  + prompt-toolkit==3.0.48
#  + propcache==0.2.0
#  + proto-plus==1.25.0
#  + protobuf==5.28.3
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==18.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.9.2
#  + pydantic-core==2.23.4
#  + pydantic-settings==2.6.1
#  + pygments==2.18.0
#  + pyjwt==2.9.0
#  + pylance==0.19.1
#  + pypdf==5.1.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.388
#  + pysbd==0.3.4
#  + pysocks==1.7.1
#  + pytest==8.3.3
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.12.1
#  + referencing==0.35.1
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.21.0
#  + rsa==4.9
#  + schema==0.7.7
#  + selenium==4.26.1
#  + setuptools==75.3.0
#  + shapely==2.0.6
#  + shellingham==1.5.4
#  + six==1.16.0
#  + sniffio==1.3.1
#  + sortedcontainers==2.4.0
#  + soupsieve==2.6
#  + sqlalchemy==2.0.36
#  + stack-data==0.6.3
#  + starlette==0.41.2
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.3
#  + tomli==2.0.2
#  + tomli-w==1.1.0
#  + tqdm==4.67.0
#  + traitlets==5.14.3
#  + trio==0.27.0
#  + trio-websocket==0.11.1
#  + typer==0.13.0
#  + types-requests==2.32.0.20241016
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2024.2
#  + urllib3==2.2.3
#  + uv==0.5.0
#  + uvicorn==0.32.0
#  + uvloop==0.21.0
#  + watchfiles==0.24.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==13.1
#  + wrapt==1.16.0
#  + wsproto==1.2.0
#  + yarl==1.17.1
#  + zipp==3.20.2

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# Here is a list of 10 bullet points highlighting the most relevant information about AI LLMs in 2024:
#
# 1. **Enhanced Multimodal Capabilities**: The latest AI LLMs have significantly improved their ability to process and generate content across multiple modalities, including text, images, and audio. This evolution allows for more integrated applications, such as generating descriptive captions from images or creating video content with synchronized narrative.
#
# 2. **Domain-Specific Models**: There has been a noticeable shift towards developing domain-specific LLMs tailored for industries like healthcare, finance, and legal sectors. These models utilize specialized training datasets to enhance accuracy and relevance in professional applications.
#
# 3. **Energy-Efficient Algorithms**: Research in 2024 has led to the development of more energy-efficient algorithms for training and deploying LLMs. Techniques such as model pruning, quantization, and using sparse architectures help reduce the computational costs and environmental impact of running these models.
#
# 4. **Fine-Tuning Frameworks**: New approaches for fine-tuning models have emerged, allowing users to adapt large pre-trained LLMs to specific tasks with fewer data and in a fraction of the time previously required. Techniques like few-shot learning and low-shot training have gained traction.
#
# 5. **Improved Interpretability and Explainability**: Efforts in 2024 are focused on enhancing interpretability in LLM outputs. Research has led to better methodologies for understanding model decisions, helping to mitigate risks associated with model biases and ensuring ethical applications.
#
# 6. **Real-Time Collaboration Tools**: The integration of LLMs into real-time collaboration platforms has seen significant advancements. Features such as intelligent editing, context-aware suggestions, and seamless communication enhancements help users enhance productivity and creativity collaboratively.
#
# 7. **Regulation and Ethical Frameworks**: As LLM applications become pervasive, there's a growing emphasis on regulatory measures governing data privacy, ethical AI deployment, and transparency. Organizations are increasingly accountable for ensuring that their AI systems comply with emerging standards.
#
# 8. **Universal Language Support**: AI LLMs now offer significantly improved multilingual capabilities, with practical applications in real-time translation and cross-lingual understanding. This supports global communication, making AI tools accessible to non-English speakers and promoting inclusiveness.
#
# 9. **Augmented Creative Applications**: In the creative domains, LLMs are generating innovative solutions in content creation, from composing music to writing scripts, and even designing logos. These capabilities foster new collaborations between AI and human creatives.
#
# 10. **Community-Driven Development**: Open-source initiatives and collaborative platforms have gained traction, enabling developers and researchers to share advancements, datasets, and models. This community-driven approach accelerates innovation and facilitates faster improvements in AI LLM capabilities.
#
# These points encapsulate the current landscape of AI LLMs as of 2024, illustrating their technological advancements, practical applications, and the changing regulatory and community-driven environment surrounding them.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # The Landscape of AI LLMs in 2024
#
# As we move into 2024, the landscape of Artificial Intelligence Language Models (AI LLMs) has evolved significantly, demonstrating remarkable advancements across various dimensions. This report delves into ten critical aspects of AI LLMs, detailing their capabilities, applications, and the frameworks surrounding their development.
#
# ## 1. Enhanced Multimodal Capabilities
#
# In 2024, AI LLMs have showcased enhanced multimodal capabilities, effectively processing and generating content across various forms, including text, images, and audio. This advancement has led to more integrated applications, enabling functionalities such as automatic caption generation for images and the creation of video content synchronized with narrative voices. The ability to seamlessly combine these modalities opens up new avenues for personalization and enriched user experiences in fields such as digital marketing, education, and entertainment. The incorporation of multimodal capabilities signifies a shift towards a more comprehensive understanding of and interaction with content, making AI LLMs vital tools in a creator's toolkit.
#
# ## 2. Domain-Specific Models
#
# The trend towards developing domain-specific LLMs has gained momentum, particularly within critical industries like healthcare, finance, and legal sectors. These specialized models are trained on datasets that are tailored to their respective fields, which significantly enhances their accuracy and relevance in professional applications. For instance, in healthcare, LLMs can understand medical terminology and assist in diagnosis and patient communication. In finance, they provide more nuanced analytical capabilities, while in law, they can parse complex legal texts and assist with case analysis. This shift not only boosts operational efficiency but also ensures that industry professionals can leverage AI tools without needing extensive AI knowledge.
#
# ## 3. Energy-Efficient Algorithms
#
# In response to growing concerns about the environmental impact of AI technology, 2024 has witnessed the development of more energy-efficient algorithms for training and deploying LLMs. Innovations such as model pruning (removing less useful parts of the model), quantization (reducing the precision of the numbers used in calculations), and sparse architectures (using only a fraction of model parameters) contribute to lowering computational costs and environmental footprints. By optimizing resource usage, these algorithms pave the way for more sustainable AI practices, addressing essential concerns around energy consumption while maintaining model performance.
#
# ## 4. Fine-Tuning Frameworks
#
# The emergence of innovative fine-tuning frameworks enables users to adapt large pre-trained LLMs to specific tasks efficiently. Techniques such as few-shot and low-shot learning have gained notable recognition, allowing users to tailor models with minimal data and in shorter timeframes compared to traditional methods. This evolution democratizes access to sophisticated AI tools, enabling smaller businesses and individual developers to leverage advanced language models for specialized applications without needing vast datasets, thus accelerating innovation across various sectors.
#
# ## 5. Improved Interpretability and Explainability
#
# With heightened awareness regarding algorithmic biases, there is a concerted effort in 2024 towards improving the interpretability and explainability of LLM outputs. Research indicates that more robust methodologies are being devised to help users understand model decisions, which is critical in mitigating bias-related risks and ensuring ethical AI usage. As organizations increasingly prioritize transparency, the ability to elucidate how models arrive at specific conclusions fosters greater trust and provides a framework for accountability in AI applications.
#
# ## 6. Real-Time Collaboration Tools
#
# Artificial Intelligence LLMs have made significant inroads in real-time collaboration tools, enhancing productivity and creativity for users. Features such as intelligent editing, context-aware suggestions, and real-time communication improvements facilitate seamless collaboration among teams. These advancements not only improve workflow by keeping users aligned with project objectives but also enable creative brainstorming sessions to flourish. The integration of AI into collaboration platforms embodies the future of team interaction, where technology enhances human creativity and efficiency.
#
# ## 7. Regulation and Ethical Frameworks
#
# As AI LLMs proliferate in various facets of society, regulatory and ethical considerations are more crucial than ever. The emphasis on establishing frameworks governing data privacy, ethical AI deployment, and operational transparency has intensified. Organizations now face increased accountability to ensure their AI systems comply with emerging regulatory standards. Such frameworks aim to protect user rights, minimize bias, and promote responsible AI use, underpinning the need for ethical stewardship in AI advancements.
#
# ## 8. Universal Language Support
#
# One of the landmark advancements in 2024 has been the significant improvement in multilingual capabilities offered by AI LLMs. These models now facilitate real-time translation and cross-lingual understanding, breaking down language barriers and enhancing global communication. By providing support for an extensive range of languages, the accessibility of AI tools increases, allowing individuals from non-English speaking backgrounds to utilize these technologies fully. This universal language support fosters inclusivity, enabling wider participation in digital interactions and collaborative opportunities.
#
# ## 9. Augmented Creative Applications
#
# AI LLMs have also transformed the creative sector in profound ways. They are now capable of generating innovative solutions in content creation, including composing music, writing scripts, and designing logos. This fusion of AI and human creativity opens new avenues for artistic collaboration and exploration. By acting as creative partners, LLMs inspire human creators, streamline the creative process, and introduce novel ideas that can elevate artistic works beyond traditional boundaries.
#
# ## 10. Community-Driven Development
#
# The trend towards community-driven development within the AI space has strengthened in 2024, with open-source initiatives and collaborative platforms emerging as vital components of progress. These platforms enable developers, researchers, and practitioners to share advancements, datasets, and models, fostering an ecosystem of innovation and knowledge-sharing. By embracing this community-centric approach, AI LLM capabilities are enhanced at an accelerated pace, leading to more robust models and solutions that reflect the collective efforts of the community.
#
# ---
#
# In summary, the advancements in AI LLMs in 2024 illustrate a conscious effort towards creating more effective, efficient, and ethical AI tools. The integration of sophisticated capabilities such as multimodal processing, domain specialization, energy efficiency, and collaborative frameworks, combined with a commitment to regulatory compliance and community development, positions AI LLMs as indispensable assets in the evolving technological landscape.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
